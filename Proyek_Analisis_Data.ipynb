# %% [markdown]
# <a href="https://colab.research.google.com/github/AxelTheAxcelian/Data-by-data-Streamlit/blob/main/Proyek_Analisis_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Juniyara Parisya Setiawan
# - **Email:** parissajuniara@gmail.com
# - **ID Dicoding:** juniyaraparisya

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - what is the total of bike Sharing ?
# - How many bike Sharing in Working day ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
! pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 32.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import datetime

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/AxelTheAxcelian/Data-by-data-Streamlit/main/Data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv("https://raw.githubusercontent.com/AxelTheAxcelian/Data-by-data-Streamlit/main/Data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# #### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# cek duplikasi

# %%
print("Duplicate :",  day_df.duplicated().sum())
# Out:
# Duplicate : 0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# #### Cleaning Data

# %% [markdown]
# Data duplikat

# %%
day_df.duplicated().sum()

# %%
day_df.drop_duplicates(inplace=True)

# %%
print("Duplicate: ", day_df.duplicated().sum())

# %%
day_df.yr.value_counts()

# %% [markdown]
# ### mengubah tipe data [dteday]

# %%
def calculate_total_bike_usage_in_year(df):
        df['dteday'] = pd.to_datetime(df['dteday'])
        daily_rentals = df.resample('D', on='dteday')['cnt'].sum()
        return daily_rentals

# %%
total_bike_usage_in_year = calculate_total_bike_usage_in_year(day_df)
st.write("Total bike usage in one year:", total_bike_usage_in_year.sum())
day_df['month'] = day_df['dteday'].dt.month

# %% [markdown]
# ### Mengubah tipe data [cnt]

# %%
def calculate_daily_bike_usage_on_working_days(df):
        working_day_df = df[df['workingday'] == 1]
        daily_rentals = working_day_df.groupby('dteday')['cnt'].sum().reset_index()
        return daily_rentals

# %%
daily_bike_usage_working_day = calculate_daily_bike_usage_on_working_days(day_df)
day_counts = daily_bike_usage_working_day['dteday'].dt.day_name().value_counts()
total_bike_usage_working_day = daily_bike_usage_working_day['cnt'].sum()
st.write("Total bike usage on working days:", total_bike_usage_working_day)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
day_df.describe(include="all")

# %% [markdown]
# ### Cek Tahun Bike Sharing

# %%
day_df.groupby(by="yr").instant.nunique().sort_values(ascending=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: what is the total of bike Sharing ?

# %%
fig, ax = plt.subplots(figsize=(10, 7))
month_totals = day_df.groupby('month')['cnt'].sum()
ax.bar(month_totals.index, month_totals.values)
ax.set_xlabel('Month')
ax.set_ylabel('Total Bike Usage')
plt.title("Jumlah Sharing in a Year)")
plt.xlabel("Musim")
plt.ylabel("Jumlah Peminjam")
plt.xticks(month_totals.index, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: How many bike Sharing in Working day ?

# %%
fig, ax = plt.subplots(figsize=(10, 7))
plt.bar(day_counts.index, day_counts.values)
plt.xlabel('Day of the Week')
plt.ylabel('Frequency of Bike Sharing')
plt.title('Jumlah Sharing in Working day')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# Total penggunaan sepeda dalam satu tahun adalah sekitar 3292679. Penggunaan sepeda cendrung meningkat dari bulan mei sampai oktober dikarenakan dibulan tersebut cendrung cuaca lebih hangat. Bulan Januari- februari dan november-desember cendrung pengguna sepeda cendrung menurung karena cuaca lebih dingin
#
# - Conclution pertanyaan 2
# Penggunaan sepeda pada hari senin cendrung menurun karena masuk hari kerja atau working days.
